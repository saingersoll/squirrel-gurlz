# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

penguins = sns.load_dataset("penguins")

# %%
penguins['sex'] = pd.Categorical(penguins['sex'], categories=penguins['sex'].dropna().unique())

# %%
penguins['species' ]= penguins['species'].astype('category').cat.codes
penguins['island'] = penguins['island'].astype('category').cat.codes
penguins['sex'] = penguins['sex'].astype('category').cat.codes
penguins.corr()
# Out:
#                     species    island  bill_length_mm  bill_depth_mm  \
# species            1.000000 -0.635659        0.731369      -0.744076
# island            -0.635659  1.000000       -0.353647       0.571035
# bill_length_mm     0.731369 -0.353647        1.000000      -0.235053
# bill_depth_mm     -0.744076  0.571035       -0.235053       1.000000
# flipper_length_mm  0.854307 -0.565825        0.656181      -0.583851
# body_mass_g        0.750491 -0.561515        0.595110      -0.471916
# sex               -0.008559 -0.029246       -0.271440      -0.311460
#
#                    flipper_length_mm  body_mass_g       sex
# species                     0.854307     0.750491 -0.008559
# island                     -0.565825    -0.561515 -0.029246
# bill_length_mm              0.656181     0.595110 -0.271440
# bill_depth_mm              -0.583851    -0.471916 -0.311460
# flipper_length_mm           1.000000     0.871202 -0.215992
# body_mass_g                 0.871202     1.000000 -0.361224
# sex                        -0.215992    -0.361224  1.000000

# %%
# Compute the correlation matrix
corr = penguins.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Generate a custom diverging colormap
cmap = sns.color_palette("flare", as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0.5,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %%
penguins2 = sns.load_dataset("penguins")

# %%
sns.set_theme(style="darkgrid")
plt.subplots(figsize=(10, 7))
# Draw a combo histogram and scatterplot with density contours

sns.kdeplot(data = penguins2, x = "body_mass_g", y = "flipper_length_mm", levels = 5, linewidths = 1.5, fill = "icefire")
sns.histplot(data = penguins2, x = "body_mass_g", y = "flipper_length_mm", bins=50, cmap = "crest", thresh = .5)
sns.scatterplot(data = penguins2, x = "body_mass_g", y = "flipper_length_mm", s=10, hue = "species", palette = "BuPu")
# Out:
# c:\Users\krist\anaconda3\envs\squirrelgurlz\lib\site-packages\seaborn\distributions.py:1185: UserWarning: linewidths is ignored by contourf
#   cset = contour_func(
# <Axes: xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.color_palette.html
#
# https://stackoverflow.com/questions/51241575/calculate-correlation-between-columns-of-strings
#
# https://seaborn.pydata.org/generated/seaborn.histplot.html
#
# https://seaborn.pydata.org/generated/seaborn.kdeplot.html
